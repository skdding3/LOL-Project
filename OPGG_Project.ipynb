# %% [markdown]
# <a href="https://colab.research.google.com/github/skdding3/OPGG-Project/blob/main/OPGG_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #OP.GG 랭크게임 데이터 분석

# %% [markdown]
# 1. 'seasonid'
# - 경기가 진행된 시기의 진행 시즌 정보
# - 삭제 추천
# - lol 10.18 버전 패치 : 대략 2020년 9월 3일 적용
# - lol 10.19 버전 패치 : 대략 2020년 9월 18일 적용
# - 시즌 변화는 거의 1년 주기로 변경 됨
#
# 2. 'queueid'
# - 어떤 형태의 게임이 진행됫는지에 대한 정보
# - ex : 소환사의 협곡 5:5 솔로 랭크
# - id 420 : 5v5 Ranked Solo games
# - id 4  : 5v5 Ranked Solo games
# - 4번은 420번이 생기면서 더이상 쓰지 않기 때문에 과제 설명 상 데이터에 420만 포함되어있어야 하는 것이 맞음
#
# 'gameid'
#
# 'participantidentities'
#
# 'gameversion'
#
# 'platformid'
#
# 'gamemode'
#
# 'mapid'
#
# 'gametype'
#
# 'teams'
#
# 'participants'
#
# 'gameduration'
#
# 'gamecreation'
#
# 'participantextendedstats' :

# %%
import pandas as pd

# %%
df = pd.read_json('/content/drive/MyDrive/OP.GG/lol_kr_v1018_soloRank.json', lines=True)

# %%
N = 50
with open('/content/drive/MyDrive/OP.GG/lol_kr_v1018_soloRank.json', encoding='utf-8') as myfile:
    head = [next(myfile) for x in range(N)]
print(len(head))
for l in head:
    print(l)
# Out:
# 50
# ...
